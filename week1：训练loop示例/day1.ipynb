# %%
import torch

# %% [markdown]
# 1.创建随机矩阵，每个元素服从标准正态

# %%
# 不管矩阵的尺寸是什么，它都是二维列表，每一个元素就是一行
m1 = torch.rand(3, 4)
m1
# Out:
# tensor([[0.6285, 0.6468, 0.1157, 0.9386],
#         [0.4648, 0.8057, 0.4478, 0.0875],
#         [0.4476, 0.0783, 0.7824, 0.5949]])

# %% [markdown]
# 2.矩阵乘法@

# %%
m2 = torch.ones(4, 3)
m2
m1 @ m2
# Out:
# tensor([[2.3297, 2.3297, 2.3297],
#         [1.8057, 1.8057, 1.8057],
#         [1.9033, 1.9033, 1.9033]])
